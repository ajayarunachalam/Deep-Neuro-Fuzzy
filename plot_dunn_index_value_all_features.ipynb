# %%
import numpy as np
# %matplotlib inline  
import matplotlib.pyplot as plt

# %%
hd_di = np.array([0.01456753, 0.02185129, 0.01466432, 0.01833040, 0.01038013,
                  0.01281077, 0.01479261, 0.01653864])

rf_di = np.array([0.06102516, 0.02657610, 0.02657610, 0.02266417, 0.01602599, 
                  0.01602599, 0.02657610, 0.02657610])

tp_di = np.array([0.012215425, 0.012215425, 0.009973853, 0.009973853, 0.009973853,
                  0.009973853, 0.009973853, 0.009973853])

wd_di = np.array([0.02115774, 0.01004328, 0.01587982, 0.01420334, 0.01420334, 
                  0.01420334, 0.01090979, 0.01090979])

ph_di = np.array([0.03254292, 0.02114007, 0.01131325, 0.01803877, 0.01041469,
                  0.01041469, 0.01803877, 0.01041469])

# %%
xpts = range(2, 10)
plt.plot(xpts, hd_di, marker = 's')
plt.plot(xpts, rf_di, marker = "*")
plt.plot(xpts, tp_di, marker = "+")
plt.plot(xpts, wd_di, marker = "^")
plt.plot(xpts, ph_di, marker = "o")
plt.xlabel('Number of Cluster', fontsize=11)
plt.ylabel('Dunn Index Value', fontsize=11)
plt.legend(['Humidity', 'Rainfall', 'Temperature', 'Wind', 'Peak Hour'],
           loc='upper right', fontsize=9)
plt.show()
